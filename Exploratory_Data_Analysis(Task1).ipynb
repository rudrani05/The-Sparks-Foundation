# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# ## Exploratory Data Analysis - Retail (Task1)

# %% [markdown]
# ### Importing important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('SampleSuperstore.csv')
dataset.head(10)
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
# 5  Standard Class   Consumer  United States  ...        7     0.00   14.1694
# 6  Standard Class   Consumer  United States  ...        4     0.00    1.9656
# 7  Standard Class   Consumer  United States  ...        6     0.20   90.7152
# 8  Standard Class   Consumer  United States  ...        3     0.20    5.7825
# 9  Standard Class   Consumer  United States  ...        5     0.00   34.4700
#
# [10 rows x 13 columns]

# %% [markdown]
# ### Full summary of dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Shape of dataset

# %%
dataset.shape
# Out:
# (9994, 13)

# %% [markdown]
# ### Print Random nine row

# %%
dataset.sample(9)
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount    Profit
# 7212  Standard Class    Corporate  United States  ...        3      0.2    3.9312
# 8079  Standard Class  Home Office  United States  ...        8      0.2   46.9952
# 1438        Same Day     Consumer  United States  ...        5      0.3 -350.4900
# 2032  Standard Class    Corporate  United States  ...        2      0.2    3.2872
# 8969  Standard Class    Corporate  United States  ...        9      0.2    1.7262
# 1342     First Class    Corporate  United States  ...        6      0.7  -21.1596
# 2812    Second Class  Home Office  United States  ...        3      0.0   36.3987
# 286     Second Class    Corporate  United States  ...        7      0.7 -169.3720
# 4239  Standard Class    Corporate  United States  ...        2      0.0  100.6560
#
# [9 rows x 13 columns]

# %% [markdown]
# ### Print last 5 rows

# %%
dataset.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Check the missing values

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Statistical details of dataset

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
dataset.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ### Checking duplicate values and dropping them

# %%
dataset.duplicated().sum()
# Out:
# 17

# %%
dataset.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %% [markdown]
# ### Distinct elements

# %%
dataset.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ### Correlation of dataset

# %%
dataset.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ### Covarience of dataset

# %%
dataset.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount         Profit
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404 -225045.849445
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228   69944.096586
# Quantity     9.104159e+02     278.459923    4.951113    0.003961      34.534769
# Discount     3.868704e+02      -3.627228    0.003961    0.042622     -10.615173
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173   54877.798055

# %% [markdown]
# ### Counting unique values in dataset

# %%
dataset.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370     2
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288     2
#                                             San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780     2
#                 Corporate    United States  Seattle        Washington  98105        West     Office Supplies  Paper         19.440   3         0.0        9.3312     2
# ...

# %%
dataset.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Deleting the variables

# %%
col=['Postal Code']
df=dataset.drop(columns=col,axis=1)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Visualization of the dataset

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=dataset)
plt.show()

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Heatmap of dataset

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(dataset.corr(), annot= True)
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(dataset.cov(), annot= True)
plt.show()

# %%
sns.countplot(x=dataset['Segment'])

# %%
sns.countplot(x=dataset['Region'])

# %%
plt.figure(figsize=(40,25))
sns.barplot(x=dataset['Sub-Category'], y=dataset['Profit'])

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data = dataset, color = 'r', label= 'Discount')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.hist(bins=50 ,figsize=(20,15))
plt.show()

# %%
figsize=(15,10)
sns.pairplot(df,hue='Sub-Category')

# %% [markdown]
# ### So Now we Grouped or sum the sales ,profit,discount,quantity according to every state of region and also according to sub-categories sales

# %%
grouped=pd.DataFrame(dataset.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#            Ship Mode      Segment    Category  ... Discount     Sales    Profit
# 0        First Class     Consumer   Furniture  ...     0.70   181.470 -320.5970
# 1        First Class     Consumer   Furniture  ...     0.45  1809.497  243.2526
# 2        First Class     Consumer   Furniture  ...     0.70    89.991 -152.9847
# 3        First Class     Consumer   Furniture  ...     0.20   314.352  -15.7176
# 4        First Class     Consumer   Furniture  ...     0.00   354.900   88.7250
# ...              ...          ...         ...  ...      ...       ...       ...
# 2978  Standard Class  Home Office  Technology  ...     0.60   808.704   77.9712
# 2979  Standard Class  Home Office  Technology  ...     0.00  1294.750  336.6350
# ...

# %% [markdown]
# ### sum,mean,min,max,count median,standard deviation,Variance of each states of Profit

# %%
dataset.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean  ...         std            var
# State                                         ...
# Alabama                5786.8253   94.865989  ...  210.901876   44479.601429
# Arizona               -3427.9246  -15.303235  ...  109.266267   11939.117124
# Arkansas               4008.6871   66.811452  ...  123.249880   15190.532873
# California            76381.3871   38.171608  ...   97.691593    9543.647400
# Colorado              -6527.8579  -35.867351  ...  276.424024   76410.240842
# Connecticut            3511.4918   42.823071  ...   66.138081    4374.245726
# Delaware               9977.3748  103.930988  ...  518.953513  269312.749126
# District of Columbia   1059.5893  105.958930  ...  213.461353   45565.749398
# Florida               -3399.3017   -8.875461  ...  126.324165   15957.794770
# Georgia               16250.0433   88.315453  ...  283.026694   80104.109456
# Idaho                   826.7231   39.367767  ...   63.027976    3972.525785
# ...

# %%
x = dataset.iloc[:, [9, 10, 11, 12]].values
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0).fit(x)
    wcss.append(kmeans.inertia_)

sns.set_style("whitegrid") 
sns.FacetGrid(dataset, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Quantity')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
sns.pairplot(df)

# %%
fig, axes = plt.subplots(figsize = (10 , 10))

sns.boxplot(dataset['Sales'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, axes = plt.subplots(figsize = (10 , 10))

sns.boxplot(dataset['Discount'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, axes = plt.subplots(figsize = (10 , 10))

sns.boxplot(dataset['Profit'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = dataset.quantile(q = 0.25, axis = 0, numeric_only = True, interpolation = 'linear')

Q3 = dataset.quantile(q = 0.75, axis = 0, numeric_only = True, interpolation = 'linear')

# %%
IQR = Q3 - Q1

print(IQR)
# Out:
# Postal Code    66785.00000
# Sales            192.66000
# Quantity           3.00000
# Discount           0.20000
# Profit            27.63525
# dtype: float64

# %%
dataset.value_counts().nlargest().plot(kind = 'bar' , figsize = (10 , 5))

# %% [markdown]
# ### SCATTER PLOT

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(dataset["Sales"] , dataset["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %% [markdown]
# ### Distribution Plot

# %%
print(dataset['Sales'].describe())
plt.figure(figsize = (9 , 8))
sns.distplot(dataset['Sales'], color = 'b', bins = 100, hist_kws = {'alpha': 0.4});
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
